# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %%
# Check the keys

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two hours ago, it was as long after one o'clock in the afternoon as it was before one o'clock in the morning yesterday, what time is it now?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's define the problem step-by-step:
#
# ### Step 1: Define variables
# - Let \( T \) be the current time (in hours and minutes).
# - The time two hours ago is \( T - 2 \).
#
# ### Step 2: Understand the problem
# Two hours ago, the time was equally distant from:
# - 1:00 PM (yesterday's afternoon) — actually 1:00 PM today, since "one o'clock in the afternoon" generally refers to 1:00 PM today.
# - 1:00 AM yesterday
#
# Wait, this needs careful interpretation of the problem statement:
#
# **The statement:**
# "If two hours ago, it was as long after one o'clock in the afternoon as it was before one o'clock in the morning yesterday..."
#
# This means:
# - Two hours ago, the amount of time that had elapsed since 1:00 PM (afternoon) was equal to
# - The amount of time that remained before 1:00 AM (morning) **yesterday**
#
# ---
#
# ### Step 3: Assign time frames correctly
# - "One o'clock in the afternoon" = 1:00 PM (the same day or just the nearest)
# - "One o'clock in the morning yesterday" = 1:00 AM yesterday (early morning of the previous day)
#
# ---
#
# ### Step 4: Express two hours ago time as \( t \)
#
# Let's represent all times on a 24-hour clock for easier calculation, using hours after midnight:
#
# - 1:00 AM yesterday = previous day at 01:00 (24 hours before plus 1 hour) = \(-23\) hours if today 0:00 is midnight today.
# - 1:00 PM today = 13:00 = 13 hours today.
#
# Two hours ago, the time was \( t \) (in hours from 0:00 today).
#
# We are to find \( t \) such that:
#
# \[
# \text{(time after 1:00 PM today)} = \text{(time before 1:00 AM yesterday)}
# \]
#
# In hours:
#
# \[
# t - 13 = \text{time after 1:00 PM today}
# \]
#
# \[
# \text{time before 1:00 AM yesterday} = 1:00 AM yesterday - t
# \]
#
# But wait, the time \( t \) is after 1:00 PM today, so \( t - 13 \) is the amount of time after 1:00 PM today.
#
# The "before 1:00 AM yesterday" means the amount of time between \( t \) and 1:00 AM yesterday; since \( t \) is after 1:00 PM today and 1:00 AM yesterday is before, the time before 1:00 AM yesterday is:
# \[
# 1:00 \text{ AM yesterday} - t = (-23) - t
# \]
# (Honestly, negative time is confusing, maybe better to rethink the reference times.)
#
# ---
#
# ### Step 5: Use a continuous timeline
#
# Let's define the timeline more explicitly:
#
# - Let \( t \) be the number of hours after midnight today when two hours ago it was.
# - 1:00 AM yesterday is 24 hours before 1:00 AM today, which is at \(-23\) hours on this scale (because 1:00 AM yesterday is 23 hours before midnight today).
#
# - 1:00 PM today is at 13 hours after midnight today.
#
# **Given:**
# Two hours ago was \( t \).
#
# At time \( t \), two hours ago, the time difference between \( t \) and 1:00 PM today is equal to the time difference between 1:00 AM yesterday and \( t \).
#
# Expressed:
#
# \[
# t - 13 = ( -23 ) - t
# \]
#
# Because the time after 1:00 PM today is \( t - 13 \), and the time before 1:00 AM yesterday is \( (-23) - t \).
#
# Set equal:
#
# \[
# t - 13 = -23 - t
# \]
#
# ---
#
# ### Step 6: Solve for \( t \)
#
# \[
# t - 13 = -23 - t
# \]
#
# Add \( t \) to both sides:
#
# \[
# t + t - 13 = -23
# \]
#
# \[
# 2t - 13 = -23
# \]
#
# Add 13 to both sides:
#
# \[
# 2t = -10
# \]
#
# \[
# t = -5
# \]
#
# ---
#
# ### Step 7: Interpret negative time
#
# \( t = -5 \) means 5 hours before midnight today, i.e., 19:00 (7:00 PM) yesterday.
#
# But this is the time two hours ago.
#
# So, two hours ago was 7:00 PM yesterday.
#
# Therefore,
#
# \[
# \text{Current time} = t + 2 = -5 + 2 = -3
# \]
#
# Meaning 3 hours before midnight today = 21:00 (9:00 PM) yesterday.
#
# This is confusing because the problem didn't specify the range or say the time must be today.
#
# ---
#
# ### Step 8: Reconsider the interpretation of "before one o'clock in the morning yesterday"
#
# Alternatively, the problem might mean:
#
# - Two hours ago, it was as far after 1:00 PM the previous day ("in the afternoon") as it was before 1:00 AM the same day ("in the morning yesterday").
#
# If the two reference points are on the same calendar day, 1:00 PM yesterday and 1:00 AM today.
#
# Let's try this approach:
#
# - 1:00 PM yesterday → at 13:00 (day -1)
# - 1:00 AM today → at 1:00 (day 0)
#
# Let two hours ago be time \( t \) on day 0 (today, in hours after midnight).
#
# The elapsed time after 1:00 PM yesterday:
#
# \[
# t + 24 - 13 = t + 11
# \]
#
# (since 1:00 PM yesterday was 13 hours into day -1, two hours ago is \( t \) hours into day 0, so total hours since 1:00 PM yesterday is \( t + 24 - 13 = t + 11 \))
#
# The time before 1:00 AM today is:
#
# \[
# 1 - t
# \]
#
# The problem states:
#
# \[
# t + 11 = 1 - t
# \]
#
# Solve:
#
# \[
# t + 11 = 1 - t
# \]
# \[
# t + t = 1 - 11
# \]
# \[
# 2t = -10
# \]
# \[
# t = -5
# \]
#
# Again negative!
#
# Which means \( t = -5 \), two hours ago was 5 hours before midnight today → 19:00 yesterday.
#
# Therefore, current time is \( t + 2 = -5 + 2 = -3 \) hours, or 21:00 (9:00 PM) yesterday.
#
# Again outside usual "current time."
#
# ---
#
# ### Step 9: Try interpretation with both reference points on the same day
#
# Let's consider the morning and afternoon on the same day.
#
# "One o'clock in the afternoon" is 1:00 PM today (13:00).
#
# "One o'clock in the morning yesterday" is 1:00 AM the previous day.
#
# Meaning, the time difference from 1:00 AM yesterday is bigger, but the distance is equal.
#
# If two hours ago, the time was equally distant from these two times, then the two points form midpoint.
#
# So two hours ago is the midpoint between 1:00 PM today and 1:00 AM yesterday.
#
# ---
#
# ### Step 10: Calculate the midpoint time
#
# Between:
#
# - 1:00 AM yesterday (24 hours before midnight today + 1 hour) = \(-23\) hours
# - 1:00 PM today = 13 hours
#
# Midpoint:
#
# \[
# \frac{13 + (-23)}{2} = \frac{-10}{2} = -5 \text{ hours}
# \]
#
# Which matches previous findings!
#
# "Two hours ago" is 5 hours before midnight (Negative 5 hours), or 7:00 PM yesterday.
#
# Therefore, "Now" = "Two hours ago" + 2 hours = \(-5) + 2 = -3 \) hours.
#
# -3 hours equals 21:00 (9:00 PM) yesterday.
#
# ---
#
# ### Step 11: Conclusion
#
# The time "now" is **9:00 PM yesterday**, or 9:00 PM on the previous day.
#
# ---
#
# ### Step 12: Write answer properly
#
# **Answer:**
#
# \[
# \boxed{9:00 \text{ PM (21:00) yesterday}}
# \]
#
# ---
#
# # Summary
#
# The problem's phrasing places the current time yesterday at 9:00 PM. That is, if two hours ago, it was as far after 1:00 PM today as it was before 1:00 AM yesterday, the mirrored distances mean two hours ago was the midpoint between 1:00 AM yesterday and 1:00 PM today.
#
# The midpoint is 7:00 PM yesterday (two hours ago), so the current time is 9:00 PM yesterday.
#
# ---
#
# # Alternative
#
# If the problem expects an answer on the same day (today), a common interpretation would be that there is no time fitting the problem. Otherwise, the answer above is consistent with the question's timeline.
#
# ---
#
# # Final note
#
# If you want, I can also provide it in standard AM/PM format with day difference explained.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's define the problem step-by-step:
#
# ### Step 1: Define variables
# - Let \( T \) be the current time (in hours and minutes).
# - The time two hours ago is \( T - 2 \).
#
# ### Step 2: Understand the problem
# Two hours ago, the time was equally distant from:
# - 1:00 PM (yesterday's afternoon) — actually 1:00 PM today, since "one o'clock in the afternoon" generally refers to 1:00 PM today.
# - 1:00 AM yesterday
#
# Wait, this needs careful interpretation of the problem statement:
#
# **The statement:**
# "If two hours ago, it was as long after one o'clock in the afternoon as it was before one o'clock in the morning yesterday..."
#
# This means:
# - Two hours ago, the amount of time that had elapsed since 1:00 PM (afternoon) was equal to
# - The amount of time that remained before 1:00 AM (morning) **yesterday**
#
# ---
#
# ### Step 3: Assign time frames correctly
# - "One o'clock in the afternoon" = 1:00 PM (the same day or just the nearest)
# - "One o'clock in the morning yesterday" = 1:00 AM yesterday (early morning of the previous day)
#
# ---
#
# ### Step 4: Express two hours ago time as \( t \)
#
# Let's represent all times on a 24-hour clock for easier calculation, using hours after midnight:
#
# - 1:00 AM yesterday = previous day at 01:00 (24 hours before plus 1 hour) = \(-23\) hours if today 0:00 is midnight today.
# - 1:00 PM today = 13:00 = 13 hours today.
#
# Two hours ago, the time was \( t \) (in hours from 0:00 today).
#
# We are to find \( t \) such that:
#
# \[
# \text{(time after 1:00 PM today)} = \text{(time before 1:00 AM yesterday)}
# \]
#
# In hours:
#
# \[
# t - 13 = \text{time after 1:00 PM today}
# \]
#
# \[
# \text{time before 1:00 AM yesterday} = 1:00 AM yesterday - t
# \]
#
# But wait, the time \( t \) is after 1:00 PM today, so \( t - 13 \) is the amount of time after 1:00 PM today.
#
# The "before 1:00 AM yesterday" means the amount of time between \( t \) and 1:00 AM yesterday; since \( t \) is after 1:00 PM today and 1:00 AM yesterday is before, the time before 1:00 AM yesterday is:
# \[
# 1:00 \text{ AM yesterday} - t = (-23) - t
# \]
# (Honestly, negative time is confusing, maybe better to rethink the reference times.)
#
# ---
#
# ### Step 5: Use a continuous timeline
#
# Let's define the timeline more explicitly:
#
# - Let \( t \) be the number of hours after midnight today when two hours ago it was.
# - 1:00 AM yesterday is 24 hours before 1:00 AM today, which is at \(-23\) hours on this scale (because 1:00 AM yesterday is 23 hours before midnight today).
#
# - 1:00 PM today is at 13 hours after midnight today.
#
# **Given:**
# Two hours ago was \( t \).
#
# At time \( t \), two hours ago, the time difference between \( t \) and 1:00 PM today is equal to the time difference between 1:00 AM yesterday and \( t \).
#
# Expressed:
#
# \[
# t - 13 = ( -23 ) - t
# \]
#
# Because the time after 1:00 PM today is \( t - 13 \), and the time before 1:00 AM yesterday is \( (-23) - t \).
#
# Set equal:
#
# \[
# t - 13 = -23 - t
# \]
#
# ---
#
# ### Step 6: Solve for \( t \)
#
# \[
# t - 13 = -23 - t
# \]
#
# Add \( t \) to both sides:
#
# \[
# t + t - 13 = -23
# \]
#
# \[
# 2t - 13 = -23
# \]
#
# Add 13 to both sides:
#
# \[
# 2t = -10
# \]
#
# \[
# t = -5
# \]
#
# ---
#
# ### Step 7: Interpret negative time
#
# \( t = -5 \) means 5 hours before midnight today, i.e., 19:00 (7:00 PM) yesterday.
#
# But this is the time two hours ago.
#
# So, two hours ago was 7:00 PM yesterday.
#
# Therefore,
#
# \[
# \text{Current time} = t + 2 = -5 + 2 = -3
# \]
#
# Meaning 3 hours before midnight today = 21:00 (9:00 PM) yesterday.
#
# This is confusing because the problem didn't specify the range or say the time must be today.
#
# ---
#
# ### Step 8: Reconsider the interpretation of "before one o'clock in the morning yesterday"
#
# Alternatively, the problem might mean:
#
# - Two hours ago, it was as far after 1:00 PM the previous day ("in the afternoon") as it was before 1:00 AM the same day ("in the morning yesterday").
#
# If the two reference points are on the same calendar day, 1:00 PM yesterday and 1:00 AM today.
#
# Let's try this approach:
#
# - 1:00 PM yesterday → at 13:00 (day -1)
# - 1:00 AM today → at 1:00 (day 0)
#
# Let two hours ago be time \( t \) on day 0 (today, in hours after midnight).
#
# The elapsed time after 1:00 PM yesterday:
#
# \[
# t + 24 - 13 = t + 11
# \]
#
# (since 1:00 PM yesterday was 13 hours into day -1, two hours ago is \( t \) hours into day 0, so total hours since 1:00 PM yesterday is \( t + 24 - 13 = t + 11 \))
#
# The time before 1:00 AM today is:
#
# \[
# 1 - t
# \]
#
# The problem states:
#
# \[
# t + 11 = 1 - t
# \]
#
# Solve:
#
# \[
# t + 11 = 1 - t
# \]
# \[
# t + t = 1 - 11
# \]
# \[
# 2t = -10
# \]
# \[
# t = -5
# \]
#
# Again negative!
#
# Which means \( t = -5 \), two hours ago was 5 hours before midnight today → 19:00 yesterday.
#
# Therefore, current time is \( t + 2 = -5 + 2 = -3 \) hours, or 21:00 (9:00 PM) yesterday.
#
# Again outside usual "current time."
#
# ---
#
# ### Step 9: Try interpretation with both reference points on the same day
#
# Let's consider the morning and afternoon on the same day.
#
# "One o'clock in the afternoon" is 1:00 PM today (13:00).
#
# "One o'clock in the morning yesterday" is 1:00 AM the previous day.
#
# Meaning, the time difference from 1:00 AM yesterday is bigger, but the distance is equal.
#
# If two hours ago, the time was equally distant from these two times, then the two points form midpoint.
#
# So two hours ago is the midpoint between 1:00 PM today and 1:00 AM yesterday.
#
# ---
#
# ### Step 10: Calculate the midpoint time
#
# Between:
#
# - 1:00 AM yesterday (24 hours before midnight today + 1 hour) = \(-23\) hours
# - 1:00 PM today = 13 hours
#
# Midpoint:
#
# \[
# \frac{13 + (-23)}{2} = \frac{-10}{2} = -5 \text{ hours}
# \]
#
# Which matches previous findings!
#
# "Two hours ago" is 5 hours before midnight (Negative 5 hours), or 7:00 PM yesterday.
#
# Therefore, "Now" = "Two hours ago" + 2 hours = \(-5) + 2 = -3 \) hours.
#
# -3 hours equals 21:00 (9:00 PM) yesterday.
#
# ---
#
# ### Step 11: Conclusion
#
# The time "now" is **9:00 PM yesterday**, or 9:00 PM on the previous day.
#
# ---
#
# ### Step 12: Write answer properly
#
# **Answer:**
#
# \[
# \boxed{9:00 \text{ PM (21:00) yesterday}}
# \]
#
# ---
#
# # Summary
#
# The problem's phrasing places the current time yesterday at 9:00 PM. That is, if two hours ago, it was as far after 1:00 PM today as it was before 1:00 AM yesterday, the mirrored distances mean two hours ago was the midpoint between 1:00 AM yesterday and 1:00 PM today.
#
# The midpoint is 7:00 PM yesterday (two hours ago), so the current time is 9:00 PM yesterday.
#
# ---
#
# # Alternative
#
# If the problem expects an answer on the same day (today), a common interpretation would be that there is no time fitting the problem. Otherwise, the answer above is consistent with the question's timeline.
#
# ---
#
# # Final note
#
# If you want, I can also provide it in standard AM/PM format with day difference explained.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

messages = [{"role": "user", "content": "Present a pain-point in that " + response.choices[0].message.content + " industry - something challenging that might be ripe for an Agentic solution"}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea =  response.choices[0].message.content

print(business_idea)

# And repeat!
# Out:
# A significant pain-point in personalized healthcare management that is ripe for an agentic AI solution is **the fragmentation and inefficiency in coordinating care among multiple providers and systems**, leading to gaps in patient information, delayed interventions, and suboptimal health outcomes.
#
# ### Why is this a challenging pain-point?
#
# - **Disparate data silos:** Patient data is scattered across different electronic health records (EHRs), labs, pharmacies, wearables, and specialist offices, often in incompatible formats with limited interoperability.
#
# - **Manual coordination burden:** Patients and caregivers frequently bear the responsibility to communicate updates, schedule appointments, and ensure that all providers have the latest information—tasks prone to errors and omissions.
#
# - **Delayed or missed interventions:** Lack of real-time, consolidated data can delay detection of deteriorating conditions, medication conflicts, or urgent needs for lifestyle adjustments.
#
# - **Complex, dynamic health profiles:** Especially for chronic disease patients, the interplay of medications, symptoms, lifestyle changes, and emerging clinical guidelines requires continuous reconciliation—too complex for manual management.
#
# ### How agentic AI can address this:
#
# An agentic AI system could autonomously bridge information gaps by continuously aggregating and updating patient data across fragmented sources, flagging inconsistencies or risks, coordinating appointments and medication refills, and proactively alerting both patients and care teams about crucial intervention points. This would reduce the cognitive and administrative burden on patients and providers, ensuring timely, personalized, and coordinated care.
